# %% [markdown]
# ## energy splitting

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import re

# %%
with open("./fplo.out", 'r') as f:
    read = f.readlines()

read[:5]
# Out:
# ['------------------------------------------------------------------------\n',
#  '|                                                                      |\n',
#  '|    FULL-POTENTIAL LOCAL-ORBITAL MINIMUM BASIS BANDSTRUCTURE CODE     |\n',
#  '|                      FULL RELATIVISTIC VERSION                       |\n',
#  '|                                                                      |\n']

# %%
st1 = 'T=      0.00000      0.00000      0.00000'
st2 = 'spin 1: WF\('
orbit = []

for string in read:
    if re.match(st2, string):
        orbit.append(string)
    elif re.match(st1, string):
        f = open('output.txt', mode='a', encoding='utf-8', newline='\n')
        # f.write(orbit[-1])
        # f.write(string)
        f.close()

# %%
from make_table import table
full_data = table('./output.txt')
full_data
# Out:
#                orbit aft                   0
# orbit bef
# Co(003)3d+0  Co(003)3d+0  1.271064012342552j
# Co(003)3d+1  Co(003)3d+1  1.237894873735944j
# Co(003)3d+2  Co(003)3d+2  1.275913124328419j
# Co(003)3d-1  Co(003)3d-1  1.237894873735944j
# Co(003)3d-2  Co(003)3d-2  1.461892635951483j
# ...                  ...                 ...
# Si(005)3p+1  Si(005)3p+1  0.030472635471594j
# Si(005)3p-1  Si(005)3p-1  0.030472635471594j
# Si(006)3p+0  Si(006)3p+0  0.079404259528209j
# Si(006)3p+1  Si(006)3p+1  0.030472635471594j
# Si(006)3p-1  Si(006)3p-1  0.030472635471594j
#
# [76 rows x 2 columns]

# %% [markdown]
# ### Co

# %%
Co_data = full_data[full_data.index.str.match('Co\(003\)*')]
Co_data
# Out:
#                orbit aft                   0
# orbit bef
# Co(003)3d+0  Co(003)3d+0  1.271064012342552j
# Co(003)3d+1  Co(003)3d+1  1.237894873735944j
# Co(003)3d+2  Co(003)3d+2  1.275913124328419j
# Co(003)3d-1  Co(003)3d-1  1.237894873735944j
# Co(003)3d-2  Co(003)3d-2  1.461892635951483j

# %% [markdown]
# ### La

# %%
La_data = full_data[full_data.index.str.match('La\(001\)*')]
La_data
# Out:
#                orbit aft                                        0
# orbit bef
# La(001)4f+0  La(001)4f+0                       2.568240224926451j
# La(001)4f+0  La(001)5d+0  (-0.000373951658495+0.083319310589138j)
# La(001)4f+1  La(001)5d+1   (0.000226876091427+0.025922221162724j)
# La(001)4f+1  La(001)4f+3   (0.000699109292136+0.030790653582493j)
# La(001)4f+1  La(001)4f+1                       2.519796586148385j
# La(001)4f+2  La(001)5d+2  (-0.002077158472894+0.027780523889778j)
# La(001)4f+2  La(001)4f+2                       2.548963045427865j
# La(001)4f+3  La(001)5d+1   (0.000743176772089+0.047302797659814j)
# La(001)4f+3  La(001)4f+3                       2.527166099643433j
# La(001)4f+3  La(001)4f+1  (-0.000699109292136+0.030790653582493j)
# La(001)4f-1  La(001)4f-3  (-0.000699109292136+0.030790653582493j)
# La(001)4f-1  La(001)4f-1                       2.519796586148386j
# La(001)4f-1  La(001)5d-1   (0.000226876091427+0.025922221162724j)
# La(001)4f-2  La(001)5d-2   (0.000776355461693+0.154986583645714j)
# La(001)4f-2  La(001)4f-2                        2.52129929568536j
# La(001)4f-3  La(001)5d-1  (-0.000743176772089+0.047302797659814j)
# La(001)4f-3  La(001)4f-1   (0.000699109292136+0.030790653582493j)
# La(001)4f-3  La(001)4f-3                       2.527166099643432j
# La(001)5d+0  La(001)5d+0                       2.697345431181294j
# La(001)5d+0  La(001)4f+0   (0.000373951658495+0.083319310589138j)
# La(001)5d+1  La(001)4f+3  (-0.000743176772089+0.047302797659814j)
# La(001)5d+1  La(001)4f+1  (-0.000226876091427+0.025922221162724j)
# La(001)5d+1  La(001)5d+1                       2.067886449390193j
# La(001)5d+2  La(001)4f+2   (0.002077158472894+0.027780523889778j)
# La(001)5d+2  La(001)5d+2                       2.263731147219872j
# La(001)5d-1  La(001)4f-1  (-0.000226876091427+0.025922221162724j)
# La(001)5d-1  La(001)4f-3   (0.000743176772089+0.047302797659814j)
# La(001)5d-1  La(001)5d-1                       2.067886449390193j
# La(001)5d-2  La(001)5d-2                         2.9734653450238j
# La(001)5d-2  La(001)4f-2  (-0.000776355461693+0.154986583645714j)

# %%
La_data.loc[:, 'abs energy'] = (La_data[0].abs())
La_data.sort_values('abs energy', ascending=False)
# Out:
#                orbit aft                                        0 abs energy
# orbit bef
# La(001)5d-2  La(001)5d-2                         2.9734653450238j   2.973465
# La(001)5d+0  La(001)5d+0                       2.697345431181294j   2.697345
# La(001)4f+0  La(001)4f+0                       2.568240224926451j    2.56824
# La(001)4f+2  La(001)4f+2                       2.548963045427865j   2.548963
# La(001)4f+3  La(001)4f+3                       2.527166099643433j   2.527166
# La(001)4f-3  La(001)4f-3                       2.527166099643432j   2.527166
# La(001)4f-2  La(001)4f-2                        2.52129929568536j   2.521299
# La(001)4f-1  La(001)4f-1                       2.519796586148386j   2.519797
# La(001)4f+1  La(001)4f+1                       2.519796586148385j   2.519797
# La(001)5d+2  La(001)5d+2                       2.263731147219872j   2.263731
# La(001)5d-1  La(001)5d-1                       2.067886449390193j   2.067886
# La(001)5d+1  La(001)5d+1                       2.067886449390193j   2.067886
# La(001)4f-2  La(001)5d-2   (0.000776355461693+0.154986583645714j)   0.154989
# La(001)5d-2  La(001)4f-2  (-0.000776355461693+0.154986583645714j)   0.154989
# La(001)4f+0  La(001)5d+0  (-0.000373951658495+0.083319310589138j)    0.08332
# La(001)5d+0  La(001)4f+0   (0.000373951658495+0.083319310589138j)    0.08332
# La(001)5d+1  La(001)4f+3  (-0.000743176772089+0.047302797659814j)   0.047309
# La(001)4f+3  La(001)5d+1   (0.000743176772089+0.047302797659814j)   0.047309
# La(001)5d-1  La(001)4f-3   (0.000743176772089+0.047302797659814j)   0.047309
# La(001)4f-3  La(001)5d-1  (-0.000743176772089+0.047302797659814j)   0.047309
# La(001)4f-3  La(001)4f-1   (0.000699109292136+0.030790653582493j)   0.030799
# La(001)4f-1  La(001)4f-3  (-0.000699109292136+0.030790653582493j)   0.030799
# La(001)4f+3  La(001)4f+1  (-0.000699109292136+0.030790653582493j)   0.030799
# La(001)4f+1  La(001)4f+3   (0.000699109292136+0.030790653582493j)   0.030799
# La(001)5d+2  La(001)4f+2   (0.002077158472894+0.027780523889778j)   0.027858
# La(001)4f+2  La(001)5d+2  (-0.002077158472894+0.027780523889778j)   0.027858
# La(001)4f-1  La(001)5d-1   (0.000226876091427+0.025922221162724j)   0.025923
# La(001)5d+1  La(001)4f+1  (-0.000226876091427+0.025922221162724j)   0.025923
# La(001)5d-1  La(001)4f-1  (-0.000226876091427+0.025922221162724j)   0.025923
# La(001)4f+1  La(001)5d+1   (0.000226876091427+0.025922221162724j)   0.025923
